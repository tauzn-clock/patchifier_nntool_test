# %%
# Setup imports
from nntool.api import NNGraph
from nntool.api.utils import model_settings, quantization_options
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
#%matplotlib widget
import logging
logging.basicConfig(level=logging.INFO)

# %%
# Load the graph and visualize it
G = NNGraph.load_graph("patchifier_rpg.onnx")
max_activ_size, total_params = G.total_memory_usage
ops = G.total_ops
#G.draw(filepath="draw", view=True)

# Quantization and fusion
G.adjust_order()
G.fusions('scaled_match_group')
G.fusions('expression_matcher')
# Out:
# INFO:nntool.graph.manipulations.adjust_order:adding transposes to correct tensor order for AT kernels
# get_output_size: _matching_feat_encoder_conv1_Conv has a padding setting not to SAME but in reality it is, changing the original padding from (3, 3)x(3, 3) to (3, 2)x(3, 2)
# get_output_size: _matching_feat_encoder_layer2_layer2_0_conv1_Conv has a padding setting not to SAME but in reality it is, changing the original padding from (1, 1)x(1, 1) to (1, 0)x(1, 0)
# get_output_size: _ctx_feat_encoder_conv1_Conv has a padding setting not to SAME but in reality it is, changing the original padding from (3, 3)x(3, 3) to (3, 2)x(3, 2)
# get_output_size: _ctx_feat_encoder_layer2_layer2_0_conv1_Conv has a padding setting not to SAME but in reality it is, changing the original padding from (1, 1)x(1, 1) to (1, 0)x(1, 0)
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:no transposes to eliminate found
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:no further transpose sequences found
# INFO:nntool.graph.nngraph:adjusted order
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer1_layer1_0_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer1_layer1_0_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer1_layer1_1_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer1_layer1_1_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer2_layer2_0_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer2_layer2_0_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer2_layer2_1_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _matching_feat_encoder_layer2_layer2_1_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer1_layer1_0_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer1_layer1_0_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer1_layer1_1_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer1_layer1_1_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer2_layer2_0_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer2_layer2_0_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer2_layer2_1_conv1_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _ctx_feat_encoder_layer2_layer2_1_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _scorer_scorer_scorer_0_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _scorer_scorer_scorer_2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _scorer_scorer_scorer_4_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing reshape that does nothing _scorer_scorer_scorer_6_Conv_reshape_out
# INFO:nntool.graph.matches.matcher:++ fusion remove_reshapes modified graph
# INFO:nntool.graph.matches.matchers.duplicate_operations_out:removed duplicates from _matching_feat_encoder_conv1_Conv_reshape_in _ctx_feat_encoder_conv1_Conv_reshape_in
# INFO:nntool.graph.matches.matchers.duplicate_operations_out:removed duplicates from _matching_feat_encoder_conv1_Conv_reshape_in _scorer_scorer_scorer_0_Conv_reshape_in
# INFO:nntool.graph.matches.matcher:++ fusion duplicate_operations_out modified graph
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_conv1_Conv,_matching_feat_encoder_relu1_Relu into _matching_feat_encoder_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer1_layer1_0_conv1_Conv,_matching_feat_encoder_layer1_layer1_0_relu_Relu into _matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer1_layer1_0_conv2_Conv,_matching_feat_encoder_layer1_layer1_0_relu_1_Relu into _matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer1_layer1_1_conv1_Conv,_matching_feat_encoder_layer1_layer1_1_relu_Relu into _matching_feat_encoder_layer1_layer1_1_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer1_layer1_1_conv2_Conv,_matching_feat_encoder_layer1_layer1_1_relu_1_Relu into _matching_feat_encoder_layer1_layer1_1_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer2_layer2_0_conv1_Conv,_matching_feat_encoder_layer2_layer2_0_relu_Relu into _matching_feat_encoder_layer2_layer2_0_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer2_layer2_0_conv2_Conv,_matching_feat_encoder_layer2_layer2_0_relu_1_Relu into _matching_feat_encoder_layer2_layer2_0_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer2_layer2_1_conv1_Conv,_matching_feat_encoder_layer2_layer2_1_relu_Relu into _matching_feat_encoder_layer2_layer2_1_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_layer2_layer2_1_conv2_Conv,_matching_feat_encoder_layer2_layer2_1_relu_1_Relu into _matching_feat_encoder_layer2_layer2_1_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_conv1_Conv,_ctx_feat_encoder_relu1_Relu into _ctx_feat_encoder_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer1_layer1_0_conv1_Conv,_ctx_feat_encoder_layer1_layer1_0_relu_Relu into _ctx_feat_encoder_layer1_layer1_0_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer1_layer1_0_conv2_Conv,_ctx_feat_encoder_layer1_layer1_0_relu_1_Relu into _ctx_feat_encoder_layer1_layer1_0_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer1_layer1_1_conv1_Conv,_ctx_feat_encoder_layer1_layer1_1_relu_Relu into _ctx_feat_encoder_layer1_layer1_1_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer1_layer1_1_conv2_Conv,_ctx_feat_encoder_layer1_layer1_1_relu_1_Relu into _ctx_feat_encoder_layer1_layer1_1_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer2_layer2_0_conv1_Conv,_ctx_feat_encoder_layer2_layer2_0_relu_Relu into _ctx_feat_encoder_layer2_layer2_0_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer2_layer2_0_conv2_Conv,_ctx_feat_encoder_layer2_layer2_0_relu_1_Relu into _ctx_feat_encoder_layer2_layer2_0_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer2_layer2_1_conv1_Conv,_ctx_feat_encoder_layer2_layer2_1_relu_Relu into _ctx_feat_encoder_layer2_layer2_1_conv1_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_layer2_layer2_1_conv2_Conv,_ctx_feat_encoder_layer2_layer2_1_relu_1_Relu into _ctx_feat_encoder_layer2_layer2_1_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _scorer_scorer_scorer_0_Conv,_scorer_scorer_scorer_1_Relu into _scorer_scorer_scorer_0_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _scorer_scorer_scorer_2_Conv,_scorer_scorer_scorer_3_Relu into _scorer_scorer_scorer_2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _scorer_scorer_scorer_4_Conv,_scorer_scorer_scorer_5_Relu into _scorer_scorer_scorer_4_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _scorer_scorer_scorer_6_Conv,_scorer_scorer_scorer_7_MaxPool into _scorer_scorer_scorer_6_Conv_fusion
# INFO:nntool.graph.matches.matcher:++ fusion fuse_gap_convs modified graph
# INFO:nntool.graph.matches.matchers.expression_matcher:fusing nodes: MatrixDivNode("_Div"),ConstantInputNode("_Constant") into expr_0
# INFO:nntool.graph.types.expression_fusion:expression decomposed into 0 intermediate and 1 output expressions
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.matches.matchers.expression_matcher:fusing nodes: MatrixDivNode("_Div_1"),ConstantInputNode("_Constant_1") into expr_1
# INFO:nntool.graph.types.expression_fusion:expression decomposed into 0 intermediate and 1 output expressions
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.matches.matcher:++ fusion expression_matcher modified graph
# INFO:nntool.graph.matches.matchers.remove_reshapes:unnecessary reshape found after _matching_feat_encoder_Reshape
# INFO:nntool.graph.matches.matchers.remove_reshapes:removing unnecessary reshape or transpose _matching_feat_encoder_conv1_Conv_reshape_in
# INFO:nntool.graph.matches.matcher:++ fusion remove_reshapes modified graph
# INFO:nntool.graph.matches.matchers.move_node_up:Node expr_0 can be moved
# INFO:nntool.graph.matches.matchers.move_node_up:Node expr_1 can be moved
# INFO:nntool.graph.matches.matchers.move_node_up:Moving node expr_0 between _matching_feat_encoder_conv2_Conv and _matching_feat_encoder_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matchers.move_node_up:Moving node expr_1 between _ctx_feat_encoder_conv2_Conv and _ctx_feat_encoder_conv2_Conv_reshape_out
# INFO:nntool.graph.matches.matcher:++ fusion move_activations_up modified graph
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _matching_feat_encoder_conv2_Conv,expr_0 into _matching_feat_encoder_conv2_Conv_fusion
# INFO:nntool.graph.matches.matchers.fuse_gap_convs:fusing nodes _ctx_feat_encoder_conv2_Conv,expr_1 into _ctx_feat_encoder_conv2_Conv_fusion
# INFO:nntool.graph.matches.matcher:++ fusion fuse_gap_convs modified graph
# INFO:nntool.graph.matches.matcher:++ fusion scaled_match_group modified graph

# %%
# Get statistics
multiple_input_for_statistics = np.load("./statistics_small.npy")[:5]
stats = G.collect_statistics(multiple_input_for_statistics)

G.quantize(
    statistics=stats,
    graph_options=quantization_options(
        #weight_bits=8,
        use_ne16=True,
        hwc=True
    ),
)
# Out:
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.manipulations.adjust_order:adding transposes to correct tensor order for AT kernels
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_conv1_Conv_fusion_trans_in0 upwards - 3 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_conv1_Conv_fusion_trans_in1 upwards - 1 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_conv2_Conv_fusion_trans_in0 upwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_conv2_Conv_fusion_trans_out0 downwards - 1 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_layer1_layer1_0_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_layer1_layer1_0_conv2_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_layer1_layer1_1_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_layer1_layer1_1_conv2_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_layer2_layer2_0_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_layer2_layer2_0_conv2_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _ctx_feat_encoder_layer2_layer2_1_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_conv1_Conv_fusion_trans_in1 upwards - 1 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_conv2_Conv_fusion_trans_in0 upwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_conv2_Conv_fusion_trans_out0 downwards - 1 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_layer1_layer1_1_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_layer1_layer1_1_conv2_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_layer2_layer2_0_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_layer2_layer2_0_conv2_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _matching_feat_encoder_layer2_layer2_1_conv1_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _scorer_scorer_scorer_0_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _scorer_scorer_scorer_2_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _scorer_scorer_scorer_4_Conv_fusion_trans_out0 downwards - 2 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:found elimination for _scorer_scorer_scorer_6_Conv_fusion_trans_out0 upwards - 1 eliminated
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:eliminate transposes
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:no transposes to eliminate found
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.nngraph:update graph dimensions
# INFO:nntool.graph.manipulations.eliminate_transposes.eliminate_transposes:no further transpose sequences found
# INFO:nntool.graph.nngraph:adjusted order
# INFO:nntool.graph.nngraph:update graph dimensions

# %%
# Get input
input_data = multiple_input_for_statistics[0][np.newaxis, :]
input_data = np.transpose(input_data, (0, 1, 3, 4, 2)) # NHWC --> NCHW

#Quantised execution
quant_execution = G.execute([input_data], quantize=True, dequantize=True)

# %%
# Execution on target on GVSOC
input_for_gap9 = G.execute([input_data], dequantize=False, quantize=True)

for input_node in G.input_nodes():
    input_node.allocate = 1

for output_node in G.output_nodes():
    output_node.allocate = 1
    output_node.at_options.out_home_mem_loc = "AT_MEM_L3_DEFAULTRAM"

work_dir = "test_tutorial"
res = G.execute_on_target(
    pmsis_os='freertos',
    platform="gvsoc",
    directory=work_dir,
    input_tensors=input_for_gap9[0],
    write_out_to_file=True,
    settings=model_settings(
        l1_size=108000,
        l2_size=800000, #Change overall L2 allowed here
        l3_size=16000000, #Change overall L3 allowed here
        tensor_directory='./tensors',
        graph_const_exec_from_flash=True,
        #graph_checksum=True,
        graph_dump_tensor=6, # Uncomment this line to dump tensor, cannot run with checksum
        graph_dump_tensor_to_file=True # Uncomment this line to dump tensor to file, cannot run with checksum
    ),
    at_loglevel=2,
    print_output=True
)
# Out:
# INFO:nntool.graph.nngraph:update graph dimensions
# Script started, output log file is '/tmp/tmppkpwpu8d/log.txt'.
# The target board you have sourced is : gap9_evk, GAP9_V2.
# Release version: 5.20.4
# -- [SDK] Version: 5.20.4
# -- [Platform] GVSoC
# -- [OS] FreeRTOS (Scheduler v2)
# -- [Printf] Semihost
# -- [Board] GAP Family : 9
# -- [Board] GAP Version : 2
# -- [AutoTiler] Setup model: patchifier_rpg
# -- Clock speeds - Cluster 370 FC 370 Peripheral 370
# -- [Log] none
#
# --- patchifier_rpg options ---
#
# -- [patchifier_rpg] Include directories : /home/dzhong/patchifier_nntool_test/test_tutorial;/home/dzhong/gap_sdk_private/tools/autotiler_v3/Autotiler;/home/dzhong/gap_sdk_private/tools/autotiler_v3/Emulation;/home/dzhong/gap_sdk_private/libs/gap_lib/include;/home/dzhong/gap_sdk_private/utils/power_meas_utils;/home/dzhong/gap_sdk_private/libs/include;/home/dzhong/gap_sdk_private/tools/autotiler_v3/ISP_Libraries;/home/dzhong/gap_sdk_private/tools/autotiler_v3/ISP_Libraries;/home/dzhong/gap_sdk_private/tools/autotiler_v3/CNN_Libraries;/home/dzhong/gap_sdk_private/tools/autotiler_v3/CNN_Libraries_fp32;/home/dzhong/gap_sdk_private/tools/autotiler_v3/CNN_Libraries_fp16;/home/dzhong/gap_sdk_private/tools/autotiler_v3/CNN_Libraries_fp16/CNN_Libraries_fp16x;/home/dzhong/gap_sdk_private/tools/autotiler_v3/CNN_Libraries_SQ8;/home/dzhong/gap_sdk_private/tools/autotiler_v3/CNN_Libraries_NE16;/home/dzhong/gap_sdk_private/tools/autotiler_v3/DSP_Librariesv2;/home/dzhong/gap_sdk_private/tools/autotiler_v3/DSP_Librariesv2/FastMathFunctions;/home/dzhong/patchifier_nntool_test/test_tutorial/build/BUILD_MODEL;/home/dzhong/patchifier_nntool_test/test_tutorial;/home/dzhong/patchifier_nntool_test/test_tutorial/.
# -- [patchifier_rpg] Compile options : -DCHIP_FAMILY=9;-D__GAP9__;-DCHIP_VERSION=2;-D__AUTOTILER_APP__;-I/home/dzhong/gap_sdk_private/tools/autotiler_v3/Autotiler;-I/home/dzhong/gap_sdk_private/tools/autotiler_v3/Emulation;-DF16_DSP_BFLOAT;-O3;-DAT_MODEL_PREFIX=;-DSTACK_SIZE=4096;-DSLAVE_STACK_SIZE=1024;-DFREQ_CL=370;-DFREQ_FC=370;-DFREQ_PE=370;-DPERF;-D__GAP__;-D__riscv__;-D__RISCV_ARCH_GAP__=1;-D__USE_TCDM_MALLOC__=1;-D__FC_MALLOC_NATIVE__=0;-D__L2_MALLOC_NATIVE__=0;-D__PMSIS_L2_MALLOC_NATIVE__=0;-DPMSIS_DRIVERS=1;-DFEATURE_CLUSTER;-DGAP_SDK_VERSION=5.20.4;-D__PLATFORM_GVSOC__;-D__PLATFORM__=ARCHI_PLATFORM_GVSOC;-D__FREERTOS__;-DSCHEDULER_V2;-DSCHEDULER_V3;-D__SEMIHOSTING__;-DPRINTF_SEMIHOST;-DPRINTF_DISABLE_SUPPORT_EXPONENTIAL
#
# --- End of patchifier_rpg options ---
#
# -- Configuring done (0.8s)
# -- Generating done (0.1s)
# -- Build files have been written to: /home/dzhong/patchifier_nntool_test/test_tutorial/build
# [  1%] Building C object pmsis/fll_pmu/CMakeFiles/fll_pmu_lib.dir/fll/fll.c.obj
# [  1%] Building C object pmsis/fll_pmu/CMakeFiles/fll_pmu_lib.dir/pmu/maestro_voltage.c.obj
# [  2%] Building C object pmsis/printf/CMakeFiles/pmsis_printf.dir/printf.c.obj
# [  3%] Linking C static library libpmsis_printf.a
# [  4%] Linking C static library libfll_pmu_lib.a
# [  4%] Built target pmsis_printf
# [  4%] Built target fll_pmu_lib
# [  4%] Building C object pmsis/tools/allocator/CMakeFiles/pulp_allocator.dir/src/alloc_pool.c.obj
# [  5%] Building C object pmsis/tools/allocator/CMakeFiles/pulp_allocator.dir/src/alloc.c.obj
# [  5%] Building C object pmsis/tools/allocator/CMakeFiles/pulp_allocator.dir/src/pi_malloc.c.obj
# [  6%] Linking C static library libpulp_allocator.a
# [  6%] Built target pulp_allocator
# [  6%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/errno.c.obj
# [  7%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/stdlib.c.obj
# [  7%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/string.c.obj
# [  8%] Linking C static library libfreertos_libs.a
# [  8%] Built target freertos_libs
# [  8%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/maestro/driver/maestro.c.obj
# [  9%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/maestro/driver/maestro_irq.c.obj
# [  9%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/gpio/driver/gpio.c.obj
# [ 10%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/gpio/driver/gpio_asm.S.obj
# [ 11%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/efuse/driver/efuse.c.obj
# [ 11%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/gap_iet.S.obj
# [ 12%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/udma_aes/driver/aes.c.obj
# [ 12%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/udma_aes/driver/aes_internal.c.obj
# [ 13%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/udma_aes_dual_core/driver/aes_dual_core_internal.c.obj
# [ 13%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/quiddikey/driver/quiddikey_internal.c.obj
# [ 14%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/cluster/driver/cluster.c.obj
# [ 15%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/cluster/driver/cluster-cc.S.obj
# [ 15%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/cluster/driver/cluster-pe-team.S.obj
# [ 17%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/cluster/driver/cluster-pe-workgroup.S.obj
# [ 17%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/udma_core/driver/udma_core.c.obj
# [ 18%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/fc_event/driver/fc_event.c.obj
# [ 18%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/pad/driver/pad.c.obj
# [ 19%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/utils/asm_util.S.obj
# [ 20%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/utils/ctors_dtors.c.obj
# [ 20%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/utils/host_sync_access.c.obj
# [ 21%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/utils/gap_io.c.obj
# [ 21%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/utils/pi_log.c.obj
# [ 22%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/utils/time.c.obj
# [ 22%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/utils/device.c.obj
# [ 23%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/rtos/malloc/pi_cl_malloc.c.obj
# [ 24%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/rtos/os/system_gap.c.obj
# [ 24%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/utils/startup_gap.S.obj
# [ 25%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/timer/driver/pi_timer.c.obj
# [ 26%] Building ASM object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/udma_octospi/driver/octospi_asm.S.obj
# [ 26%] Building C object pmsis/CMakeFiles/pmsis.dir/implem/chips/gap9/udma_octospi/driver/octospi.c.obj
# [ 26%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/fs/fs.c.obj
# [ 27%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/bsp/bsp.c.obj
# [ 28%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/fs/host_fs/host_fs.c.obj
# [ 28%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/fs/lfs/lfs_util.c.obj
# [ 29%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/fs/lfs/lfs.c.obj
# [ 29%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/fs/lfs/pi_lfs.c.obj
# [ 30%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/fs/read_fs/read_fs.c.obj
# [ 31%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/fs/vfs.c.obj
# [ 31%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/partition/flash_partition_v2.c.obj
# [ 32%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/partition/secret_storage.c.obj
# [ 32%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/boards/src/bsp_gap9evk_v1_3.c.obj
# [ 34%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/boards/src/bsp_gap9mod_v1_0_b.c.obj
# [ 34%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/crc/crc32/crc32.c.obj
# [ 35%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/flash/api/flash.c.obj
# [ 36%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/flash/mram/mram-v2.c.obj
# [ 36%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/flash/mx25u51245g/mx25u51245g.c.obj
# [ 37%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/powersupply/api/powersupply.c.obj
# [ 37%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/powersupply/powersupplygpio/powersupplygpio.c.obj
# [ 38%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/ram/api/alloc_extern.c.obj
# [ 39%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/ram/api/ram.c.obj
# [ 39%] Building C object pmsis/CMakeFiles/pmsis.dir/bsp/ram/aps256xxn/aps256xxn.c.obj
# [ 40%] Building C object pmsis/CMakeFiles/pmsis.dir/__/devicetree/internal/devicetree_internal.c.obj
# [ 40%] Building C object pmsis/CMakeFiles/pmsis.dir/__/devicetree/src/dt.c.obj
# [ 41%] Building C object pmsis/CMakeFiles/pmsis.dir/__/devicetree/fpv2/devicetree_fpv2.c.obj
# [ 41%] Linking C static library libpmsis.a
# [ 41%] Built target pmsis
# [ 43%] Building ASM object freertos/vendors/gwt/pmsis/backend/CMakeFiles/pmsis_backend.dir/src/main.S.obj
# [ 43%] Building C object freertos/vendors/gwt/pmsis/backend/CMakeFiles/pmsis_backend.dir/src/native_evt.c.obj
# [ 43%] Building C object freertos/vendors/gwt/pmsis/backend/CMakeFiles/pmsis_backend.dir/src/custom_list.c.obj
# [ 44%] Building C object freertos/vendors/gwt/pmsis/backend/CMakeFiles/pmsis_backend.dir/src/native_task.c.obj
# [ 44%] Building C object freertos/vendors/gwt/pmsis/backend/CMakeFiles/pmsis_backend.dir/src/sync_obj.c.obj
# [ 45%] Building C object freertos/vendors/gwt/pmsis/backend/CMakeFiles/pmsis_backend.dir/src/os.c.obj
# [ 45%] Linking C static library libpmsis_backend.a
# [ 45%] Built target pmsis_backend
# [ 46%] Building ASM object freertos/CMakeFiles/freertos.dir/freertos_kernel/portable/GCC/RI5CY-GAP9/port_asm.S.obj
# [ 46%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/portable/GCC/RI5CY-GAP9/port.c.obj
# [ 47%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/list.c.obj
# [ 47%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/queue.c.obj
# [ 48%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/tasks.c.obj
# [ 48%] Building ASM object freertos/CMakeFiles/freertos.dir/freertos_kernel/freertos_task.S.obj
# [ 51%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/timers.c.obj
# [ 51%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/event_groups.c.obj
# [ 51%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/stream_buffer.c.obj
# [ 52%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/event.c.obj
# [ 52%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/scheduler.c.obj
# [ 53%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/sync_obj-v3.c.obj
# [ 54%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/task-v3.c.obj
# [ 54%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/semaphore-v2.c.obj
# [ 55%] Building C object freertos/CMakeFiles/freertos.dir/home/dzhong/gap_sdk_private/rtos/pmsis/implem/chips/gap9/timer_os/timer.c.obj
# [ 55%] Building ASM object freertos/CMakeFiles/freertos.dir/home/dzhong/gap_sdk_private/rtos/pmsis/implem/chips/gap9/timer_os/timer_asm.S.obj
# [ 56%] Building C object freertos/CMakeFiles/freertos.dir/vendors/gwt/gap9/config/FreeRTOS_util.c.obj
# [ 56%] Building C object freertos/CMakeFiles/freertos.dir/vendors/gwt/gap9/src/device/freertos_it.c.obj
# [ 57%] Building C object freertos/CMakeFiles/freertos.dir/vendors/gwt/gap9/src/device/gap_it.c.obj
# [ 58%] Linking C static library libfreertos.a
# [ 58%] Built target freertos
# [ 59%] Building C object libs/gap_lib/CMakeFiles/gap_lib.dir/img_io/ImgIO.c.obj
# [ 60%] Building C object libs/gap_lib/CMakeFiles/gap_lib.dir/wav_io/wavIO.c.obj
# [ 60%] Linking C static library libgap_lib.a
# [ 60%] Built target gap_lib
# [ 60%] Compiling Autotiler Model : /home/dzhong/patchifier_nntool_test/test_tutorial/build/BUILD_MODEL/Genpatchifier_rpg (depends on: /home/dzhong/patchifier_nntool_test/test_tutorial/./model.c /home/dzhong/patchifier_nntool_test/test_tutorial/build/BUILD_MODEL)
# [ 61%] Running Genpatchifier_rpg to create Kernel C files : patchifier_rpgKernels.c  with args -c/home/dzhong/patchifier_nntool_test/test_tutorial/./tensors;--L1=95712;--L2=800000;--L3=16000000;--L2STATIC=-1;--L3STATIC=-1;--log_level=2;-o/home/dzhong/patchifier_nntool_test/test_tutorial/build/BUILD_MODEL
# RUNNING AUTOTILER MODEL - START
# ---------------------------------------------------------- CNN_ConvolutionNE16 MM: S4__matching_feat_encoder_conv1_Conv_fusion ---------------------------------------------------------------------------
# InFeat: 5 Im2ColSize: 245 Elements, OutFeat: 32, InFeatCons: 16
# Conv => W:   240, Pad:[3,2] PadT:[3,2] => Wc: 120, Filter:[7,7]x8 Bits
#      => H:   180, Pad:[3,2] PadT:[3,2] => Hc: 90
# NoConvOut -- >ConvOut_DataSize: 1
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 5
# OverlapP: 0
# UsedIn  : [240 x 180]
# UsedC   : [120 x 90]
#          ConvKerName: Ker_MM_Conv2DSmallv2_NE16
# Nb Oper : 84672000
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          2
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          0
# 	         QuantNoRect:          0
# 	           NormShift:          1
# 	            NormBias:          1
#
# ==== Process Tiling For User Kernel:  S4__matching_feat_encoder_conv1_Conv_fusion =======================
# S4__matching_feat_encoder_conv1_Conv_fusion Partition[0] Size =  19624 (Min:      0, Max: 470794), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                  Out, Dim=90
# 	             ColBuff Not Tiled
# 	                  In Dim: 185, TileOverlap:  5, Ratio: 2.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# S4__matching_feat_encoder_conv1_Conv_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S4__matching_feat_encoder_conv1_Conv_fusion, Arg Scale has one tile only, Buffer count = 2 is reduced to 1
# S4__matching_feat_encoder_conv1_Conv_fusion, Arg ScaleN has one tile only, Buffer count = 2 is reduced to 1
# S4__matching_feat_encoder_conv1_Conv_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# S4__matching_feat_encoder_conv1_Conv_fusion, TiledSpace: Tile0 Iteration Count: 18 Parametric Space: [D0, M0=5]
# *        ColBuff : Ratio: 0.000000,                                          Size:   4412, Total:    4412, Move:          0 (Decl x 0.000000) L2
#               In : Ratio: 2.000000, FixDim:    240, VarDim:     15 [   180], Size:  36000, Total:   40412, Move:   10176000 (Decl x 47.111111) L2
# *           Bias : Ratio: 0.000000,                                          Size:    128, Total:   40540, Move:        128 (Decl x 1.000000) L2
# *          Scale : Ratio: 0.000000,                                          Size:     32, Total:   40572, Move:         32 (Decl x 1.000000) L2
# *         ScaleN : Ratio: 0.000000,                                          Size:     32, Total:   40604, Move:         32 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   8192, Total:   48796, Move:       8192 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:    120, VarDim:      5 [    90], Size:  38400, Total:   87196, Move:     345600 (Decl x 1.000000) L2
# *          Infos : Ratio: 0.000000,                                          Size:     20, Total:   87216, Move:         20 (Decl x 1.000000) L2
# S4__matching_feat_encoder_conv1_Conv_fusion - IterSpace: Tile0 - L1 Memory:  87216, L2Move: 10530004, L3Move: 0, Tiling Overhead: 18.473562
# S4__matching_feat_encoder_conv1_Conv_fusion Found Parametric value for space D0 (Initial: 5, Div: 16) = 5 [5*1 + 0], Iteration for Tiled Space: 18
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:    ColBuff, Size:   4412, Base1:      0, Base2:      0
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:         In, Size:  18000, Base1:   4412, Base2:  22412
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:       Bias, Size:    128, Base1:  40412, Base2:      0
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:      Scale, Size:     32, Base1:  40540, Base2:      0
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:     ScaleN, Size:     32, Base1:  40572, Base2:      0
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:     Filter, Size:   8192, Base1:  40604, Base2:      0
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:        Out, Size:  19200, Base1:  48796, Base2:  67996
# Ker: S4__matching_feat_encoder_conv1_Conv_fusion, Arg:      Infos, Size:     20, Base1:  87196, Base2:      0
# S4__matching_feat_encoder_conv1_Conv_fusion For Iter Space: 0 Iteration count:  18, Given L1 Memory:  95712, Used L1 Memory:  87216, Reusable Memory: 8496, Used L2 Memory: 0
# =================================================================================================
#
# ---------------------------------------------------------- CNN_ConvolutionNE16: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion ------------------------------------------------------------------------------
# InFeat: 32 (FULL), OutFeat: 32, InFeatCons: 16
# Conv => W:   120, Pad:[1,1] PadT:[1,1] => Wc: 120, Filter:[3,3]x8 Bits
#      => H:    90, Pad:[1,1] PadT:[1,1] => Hc: 90
# NoConvOut -- >ConvOut_DataSize: 1
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 2
# OverlapP: 0
# TileCons: 3, MinTile: 0
# UsedIn  : [120 x 90]
# UsedC   : [120 x 90]
#          ConvKerName: KerConv3x3Stride1_NE16Seq
# Nb Oper : 99532800
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          0
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          0
# 	         QuantNoRect:          0
# 	           NormShift:          1
# 	            NormBias:          1
# Using Sequential NE16 call (less overhead)
#
# ==== Process Tiling For User Kernel:  S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion =======================
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion Partition[0] Size =  39755 (Min:   1200, Max: 728957), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                   In, Dim=90
# 	                  In Dim:  92, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# VarDim is 4 Not meeting Constraints (K*3) (4*1.000000=4), Adjusting to 3 (3*1.000000=3) Overflow: No DimMin: 90
# Iter was 23, Now is: 30
# VarDim is 4 Not meeting Constraints (K*3) (4*1.000000=4), Adjusting to 3 (3*1.000000=3) Overflow: No DimMin: 90
# Iter was 23, Now is: 30
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Scale has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg ScaleN has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# VarDim is 4 Not meeting Constraints (K*3) (4*1.000000=4), Adjusting to 3 (3*1.000000=3) Overflow: No DimMin: 90
# Iter was 23, Now is: 30
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, TiledSpace: Tile0 Iteration Count: 30 Parametric Space: [D0, M0=32]
#               In : Ratio: 1.000000, FixDim:    120, VarDim:      5 [    90], Size:  38400, Total:   38400, Move:   18186240 (Decl x 52.622223) L2
# *           Bias : Ratio: 0.000000,                                          Size:    128, Total:   38528, Move:        128 (Decl x 1.000000) L2
# *          Scale : Ratio: 0.000000,                                          Size:     32, Total:   38560, Move:         32 (Decl x 1.000000) L2
# *         ScaleN : Ratio: 0.000000,                                          Size:     32, Total:   38592, Move:         32 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   9216, Total:   47808, Move:       9216 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:    120, VarDim:      3 [    90], Size:  23040, Total:   70848, Move:     345600 (Decl x 1.000000) L2
# *          Infos : Ratio: 0.000000,                                          Size:     20, Total:   70868, Move:         20 (Decl x 1.000000) L2
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion - IterSpace: Tile0 - L1 Memory:  70868, L2Move: 18541268, L3Move: 0, Tiling Overhead: 26.463783
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion Found Parametric value for space D0 (Initial: 32, Div: 16) = 32 [32*1 + 0], Iteration for Tiled Space: 30
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:         In, Size:  19200, Base1:      0, Base2:  19200
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:       Bias, Size:    128, Base1:  38400, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:      Scale, Size:     32, Base1:  38528, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:     ScaleN, Size:     32, Base1:  38560, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:     Filter, Size:   9216, Base1:  38592, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:        Out, Size:  11520, Base1:  47808, Base2:  59328
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:      Infos, Size:     20, Base1:  70848, Base2:      0
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion For Iter Space: 0 Iteration count:  30, Given L1 Memory:  95712, Used L1 Memory:  70868, Reusable Memory: 24844, Used L2 Memory: 0
# =================================================================================================
#
# InFeat: 32(PART), OutFeat: 32, InFeatCons: 16
# Conv => W:   120, Pad:[1,1] PadT:[1,1] => Wc: 120, Filter:[3,3]x8 Bits
#      => H:    90, Pad:[1,1] PadT:[1,1] => Hc: 90
# NeedConvOut -- >ConvOut_DataSize: 4
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 2
# OverlapP: 0
# TileCons: 3, MinTile: 0
# UsedIn  : [120 x 90]
# UsedC   : [120 x 90]
#          ConvKerName: KerConv3x3Stride1_NE16Seq
#   DPReductionKerName: KerReduct_CC_NoScale_USQ8
# Nb Oper : 99532800
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          0
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          2
# 	         QuantNoRect:          1
# 	           NormShift:          1
# 	            NormBias:          1
# Using Sequential NE16 call (less overhead)
#
# ==== Process Tiling For User Kernel:  S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion =======================
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion Partition[0] Size = 1422158 (Min:   1200, Max: 2111408), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                   In, Dim=90
# 	                  In Dim:  92, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	             ConvOut Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	                 Out Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# VarDim is 2 Not meeting Constraints (K*3) < (2*1.000000=2), Cannot adjust
# VarDim is 2 Not meeting Constraints (K*3) < (2*1.000000=2), Cannot adjust
# Warning: For Kernel S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion: Can't find a tiling solution (gently failing). Available Memory: 95712.
# ========================== No Solution ==========================================================
#
# InFeat: 32(PART), OutFeat: 32, InFeatCons: 16
# Conv => W:   120, Pad:[1,1] PadT:[1,1] => Wc: 120, Filter:[3,3]x8 Bits
#      => H:    90, Pad:[1,1] PadT:[1,1] => Hc: 90
# NeedConvOut -- >ConvOut_DataSize: 4
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 2
# OverlapP: 0
# TileCons: 1, MinTile: 0
# UsedIn  : [120 x 90]
# UsedC   : [120 x 90]
#          ConvKerName: KerConv3x3Stride1_NE16Seq
#   DPReductionKerName: KerReduct_CC_NoScale_USQ8
# Nb Oper : 99532800
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          0
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          2
# 	         QuantNoRect:          1
# 	           NormShift:          1
# 	            NormBias:          1
# Using Sequential NE16 call (less overhead)
#
# ==== Process Tiling For User Kernel:  S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion =======================
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion Partition[0] Size = 1406318 (Min:    720, Max: 2111408), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                   In, Dim=90
# 	                  In Dim:  92, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	             ConvOut Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	                 Out Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Scale has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg ScaleN has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, TiledSpace: Tile0 Iteration Count: 45 Parametric Space: [D0, M0=32]
#               In : Ratio: 1.000000, FixDim:    120, VarDim:      4 [    90], Size:  30720, Total:   30720, Move:   21872640 (Decl x 63.288887) L2
# *           Bias : Ratio: 0.000000,                                          Size:    128, Total:   30848, Move:        128 (Decl x 1.000000) L2
# *          Scale : Ratio: 0.000000,                                          Size:     32, Total:   30880, Move:         32 (Decl x 1.000000) L2
# *         ScaleN : Ratio: 0.000000,                                          Size:     32, Total:   30912, Move:         32 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   9216, Total:   40128, Move:       9216 (Decl x 1.000000) L2
# *        ConvOut : Ratio: 1.000000, FixDim:    120, VarDim:      2 [    90], Size:  30720, Total:   70848, Move:          0 (Decl x 0.000000) L2
#              Out : Ratio: 1.000000, FixDim:    120, VarDim:      2 [    90], Size:  15360, Total:   86208, Move:     345600 (Decl x 1.000000) L2
# *          Infos : Ratio: 0.000000,                                          Size:     20, Total:   86228, Move:         20 (Decl x 1.000000) L2
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion - IterSpace: Tile0 - L1 Memory:  86228, L2Move: 22227668, L3Move: 0, Tiling Overhead: 31.725349
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion Found Parametric value for space D0 (Initial: 32, Div: 16) = 32 [32*1 + 0], Iteration for Tiled Space: 45
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:         In, Size:  15360, Base1:      0, Base2:  15360
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:       Bias, Size:    128, Base1:  30720, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:      Scale, Size:     32, Base1:  30848, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:     ScaleN, Size:     32, Base1:  30880, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:     Filter, Size:   9216, Base1:  30912, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:    ConvOut, Size:  30720, Base1:  40128, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:        Out, Size:   7680, Base1:  70848, Base2:  78528
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:      Infos, Size:     20, Base1:  86208, Base2:      0
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion For Iter Space: 0 Iteration count:  45, Given L1 Memory:  95712, Used L1 Memory:  86228, Reusable Memory: 9484, Used L2 Memory: 0
# =================================================================================================
#
# InFeat: 32 (FULL), OutFeat: 32, InFeatCons: 16
# Conv => W:   120, Pad:[1,1] PadT:[1,1] => Wc: 120, Filter:[3,3]x8 Bits
#      => H:    90, Pad:[1,1] PadT:[1,1] => Hc: 90
# NoConvOut -- >ConvOut_DataSize: 1
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 2
# OverlapP: 0
# TileCons: 3, MinTile: 0
# UsedIn  : [120 x 90]
# UsedC   : [120 x 90]
#          ConvKerName: KerConv3x3Stride1_NE16Seq
# Nb Oper : 99532800
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          0
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          0
# 	         QuantNoRect:          0
# 	           NormShift:          1
# 	            NormBias:          1
# Using Sequential NE16 call (less overhead)
#
# ==== Process Tiling For User Kernel:  S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion =======================
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion Partition[0] Size =  29975 (Min:    900, Max: 725117), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                   In, Dim=120
# 	                  In Dim: 122, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim: 120, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Scale has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg ScaleN has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, TiledSpace: Tile0 Iteration Count: 20 Parametric Space: [D0, M0=32]
#               In : Ratio: 1.000000, FixDim:     90, VarDim:      8 [   120], Size:  46080, Total:   46080, Move:   14561280 (Decl x 42.133335) L2
# *           Bias : Ratio: 0.000000,                                          Size:    128, Total:   46208, Move:        128 (Decl x 1.000000) L2
# *          Scale : Ratio: 0.000000,                                          Size:     32, Total:   46240, Move:         32 (Decl x 1.000000) L2
# *         ScaleN : Ratio: 0.000000,                                          Size:     32, Total:   46272, Move:         32 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   9216, Total:   55488, Move:       9216 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     90, VarDim:      6 [   120], Size:  34560, Total:   90048, Move:     345600 (Decl x 1.000000) L2
# *          Infos : Ratio: 0.000000,                                          Size:     20, Total:   90068, Move:         20 (Decl x 1.000000) L2
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion - IterSpace: Tile0 - L1 Memory:  90068, L2Move: 14916308, L3Move: 0, Tiling Overhead: 21.289911
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion Found Parametric value for space D0 (Initial: 32, Div: 16) = 32 [32*1 + 0], Iteration for Tiled Space: 20
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:         In, Size:  23040, Base1:      0, Base2:  23040
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:       Bias, Size:    128, Base1:  46080, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:      Scale, Size:     32, Base1:  46208, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:     ScaleN, Size:     32, Base1:  46240, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:     Filter, Size:   9216, Base1:  46272, Base2:      0
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:        Out, Size:  17280, Base1:  55488, Base2:  72768
# Ker: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Arg:      Infos, Size:     20, Base1:  90048, Base2:      0
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion For Iter Space: 0 Iteration count:  20, Given L1 Memory:  95712, Used L1 Memory:  90068, Reusable Memory: 5644, Used L2 Memory: 0
# =================================================================================================
#
# Eval [No PW or DW] CNN_ConvolutionNE16 S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion
# 	Sol1 (FULL INFEAT) : TilingOverHead=26.464 InFeatTile=  32 (Constraint:   32) T0Tile=   3 (Constraint:    3)
# 	Sol2 (TILED INFEAT): TilingOverHead=31.725 InFeatTile=  32 (Constraint:   16) T0Tile=   2 (Constraint:    1)
# 	Sol3 (TILED VER)   : TilingOverHead=21.290 InFeatTile=  32 (Constraint:   32) T0Tile=   6 (Constraint:    3)
# Chosing Sol3
# -----------------------------------------------------------------------------------------------------------------------------------------------------------
# ---------------------------------------------------------- CNN_ConvolutionNE16: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion ------------------------------------------------------------------------------
# InFeat: 32 (FULL), OutFeat: 32, InFeatCons: 16
# Conv => W:   120, Pad:[1,1] PadT:[1,1] => Wc: 120, Filter:[3,3]x8 Bits
#      => H:    90, Pad:[1,1] PadT:[1,1] => Hc: 90
# NoConvOut -- >ConvOut_DataSize: 1
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 2
# OverlapP: 0
# TileCons: 3, MinTile: 0
# UsedIn  : [120 x 90]
# UsedC   : [120 x 90]
#          ConvKerName: KerConv3x3Stride1_NE16Seq
# Nb Oper : 99532800
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          0
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          0
# 	         QuantNoRect:          0
# 	           NormShift:          1
# 	            NormBias:          1
# Using Sequential NE16 call (less overhead)
#
# ==== Process Tiling For User Kernel:  S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion =======================
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion Partition[0] Size =  39755 (Min:   1200, Max: 728957), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                   In, Dim=90
# 	                  In Dim:  92, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# VarDim is 4 Not meeting Constraints (K*3) (4*1.000000=4), Adjusting to 3 (3*1.000000=3) Overflow: No DimMin: 90
# Iter was 23, Now is: 30
# VarDim is 4 Not meeting Constraints (K*3) (4*1.000000=4), Adjusting to 3 (3*1.000000=3) Overflow: No DimMin: 90
# Iter was 23, Now is: 30
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg Scale has one tile only, Buffer count = 2 is reduced to 1
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg ScaleN has one tile only, Buffer count = 2 is reduced to 1
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# VarDim is 4 Not meeting Constraints (K*3) (4*1.000000=4), Adjusting to 3 (3*1.000000=3) Overflow: No DimMin: 90
# Iter was 23, Now is: 30
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, TiledSpace: Tile0 Iteration Count: 30 Parametric Space: [D0, M0=32]
#               In : Ratio: 1.000000, FixDim:    120, VarDim:      5 [    90], Size:  38400, Total:   38400, Move:   18186240 (Decl x 52.622223) L2
# *           Bias : Ratio: 0.000000,                                          Size:    128, Total:   38528, Move:        128 (Decl x 1.000000) L2
# *          Scale : Ratio: 0.000000,                                          Size:     32, Total:   38560, Move:         32 (Decl x 1.000000) L2
# *         ScaleN : Ratio: 0.000000,                                          Size:     32, Total:   38592, Move:         32 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   9216, Total:   47808, Move:       9216 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:    120, VarDim:      3 [    90], Size:  23040, Total:   70848, Move:     345600 (Decl x 1.000000) L2
# *          Infos : Ratio: 0.000000,                                          Size:     20, Total:   70868, Move:         20 (Decl x 1.000000) L2
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion - IterSpace: Tile0 - L1 Memory:  70868, L2Move: 18541268, L3Move: 0, Tiling Overhead: 26.463783
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion Found Parametric value for space D0 (Initial: 32, Div: 16) = 32 [32*1 + 0], Iteration for Tiled Space: 30
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:         In, Size:  19200, Base1:      0, Base2:  19200
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:       Bias, Size:    128, Base1:  38400, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:      Scale, Size:     32, Base1:  38528, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:     ScaleN, Size:     32, Base1:  38560, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:     Filter, Size:   9216, Base1:  38592, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:        Out, Size:  11520, Base1:  47808, Base2:  59328
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:      Infos, Size:     20, Base1:  70848, Base2:      0
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion For Iter Space: 0 Iteration count:  30, Given L1 Memory:  95712, Used L1 Memory:  70868, Reusable Memory: 24844, Used L2 Memory: 0
# =================================================================================================
#
# InFeat: 32(PART), OutFeat: 32, InFeatCons: 16
# Conv => W:   120, Pad:[1,1] PadT:[1,1] => Wc: 120, Filter:[3,3]x8 Bits
#      => H:    90, Pad:[1,1] PadT:[1,1] => Hc: 90
# NeedConvOut -- >ConvOut_DataSize: 4
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 2
# OverlapP: 0
# TileCons: 3, MinTile: 0
# UsedIn  : [120 x 90]
# UsedC   : [120 x 90]
#          ConvKerName: KerConv3x3Stride1_NE16Seq
#   DPReductionKerName: KerReduct_CC_NoScale_USQ8
# Nb Oper : 99532800
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          0
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          2
# 	         QuantNoRect:          1
# 	           NormShift:          1
# 	            NormBias:          1
# Using Sequential NE16 call (less overhead)
#
# ==== Process Tiling For User Kernel:  S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion =======================
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion Partition[0] Size = 1422158 (Min:   1200, Max: 2111408), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                   In, Dim=90
# 	                  In Dim:  92, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	             ConvOut Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	                 Out Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# VarDim is 2 Not meeting Constraints (K*3) < (2*1.000000=2), Cannot adjust
# VarDim is 2 Not meeting Constraints (K*3) < (2*1.000000=2), Cannot adjust
# Warning: For Kernel S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion: Can't find a tiling solution (gently failing). Available Memory: 95712.
# ========================== No Solution ==========================================================
#
# InFeat: 32(PART), OutFeat: 32, InFeatCons: 16
# Conv => W:   120, Pad:[1,1] PadT:[1,1] => Wc: 120, Filter:[3,3]x8 Bits
#      => H:    90, Pad:[1,1] PadT:[1,1] => Hc: 90
# NeedConvOut -- >ConvOut_DataSize: 4
# Pool => Wc:  120, Pad:[0,0] => Wo: 120, Filter:[1,1] 0
#      => Hc:   90, Pad:[0,0] => Ho: 90
# OverlapC: 2
# OverlapP: 0
# TileCons: 1, MinTile: 0
# UsedIn  : [120 x 90]
# UsedC   : [120 x 90]
#          ConvKerName: KerConv3x3Stride1_NE16Seq
#   DPReductionKerName: KerReduct_CC_NoScale_USQ8
# Nb Oper : 99532800
# NE16_DefaultConfig:
# 	                  Qw:          8
# 	              Mode16:          0
# 	       StreamoutMode:          1
# 	          FilterMode:          0
# 	          LinearMode:          0
# 	         StridedMode:          0
# 	            NormBits:          0
# 	            Streamin:          0
# 	          WOffsetCfg:          1
# 	     QuantRightShift:          0
# 	           QuantBits:          2
# 	         QuantNoRect:          1
# 	           NormShift:          1
# 	            NormBias:          1
# Using Sequential NE16 call (less overhead)
#
# ==== Process Tiling For User Kernel:  S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion =======================
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion Partition[0] Size = 1406318 (Min:    720, Max: 2111408), Fraction:       1.00, Giving:  95712 Bytes out of  95712 Bytes
#
# Reference object:                   In, Dim=90
# 	                  In Dim:  92, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	               Scale Not Tiled
# 	              ScaleN Not Tiled
# 	              Filter Not Tiled
# 	             ConvOut Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	                 Out Dim:  90, TileOverlap:  0, Ratio: 1.000000
# 	               Infos Not Tiled
#
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg Scale has one tile only, Buffer count = 2 is reduced to 1
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg ScaleN has one tile only, Buffer count = 2 is reduced to 1
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, TiledSpace: Tile0 Iteration Count: 45 Parametric Space: [D0, M0=32]
#               In : Ratio: 1.000000, FixDim:    120, VarDim:      4 [    90], Size:  30720, Total:   30720, Move:   21872640 (Decl x 63.288887) L2
# *           Bias : Ratio: 0.000000,                                          Size:    128, Total:   30848, Move:        128 (Decl x 1.000000) L2
# *          Scale : Ratio: 0.000000,                                          Size:     32, Total:   30880, Move:         32 (Decl x 1.000000) L2
# *         ScaleN : Ratio: 0.000000,                                          Size:     32, Total:   30912, Move:         32 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   9216, Total:   40128, Move:       9216 (Decl x 1.000000) L2
# *        ConvOut : Ratio: 1.000000, FixDim:    120, VarDim:      2 [    90], Size:  30720, Total:   70848, Move:          0 (Decl x 0.000000) L2
#              Out : Ratio: 1.000000, FixDim:    120, VarDim:      2 [    90], Size:  15360, Total:   86208, Move:     345600 (Decl x 1.000000) L2
# *          Infos : Ratio: 0.000000,                                          Size:     20, Total:   86228, Move:         20 (Decl x 1.000000) L2
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion - IterSpace: Tile0 - L1 Memory:  86228, L2Move: 22227668, L3Move: 0, Tiling Overhead: 31.725349
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion Found Parametric value for space D0 (Initial: 32, Div: 16) = 32 [32*1 + 0], Iteration for Tiled Space: 45
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:         In, Size:  15360, Base1:      0, Base2:  15360
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:       Bias, Size:    128, Base1:  30720, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:      Scale, Size:     32, Base1:  30848, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:     ScaleN, Size:     32, Base1:  30880, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:     Filter, Size:   9216, Base1:  30912, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:    ConvOut, Size:  30720, Base1:  40128, Base2:      0
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:        Out, Size:   7680, Base1:  70848, Base2:  78528
# Ker: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Arg:      Infos, Size:     20, Base1:  86208, Base2:      0
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion For Iter Space: 0 Iteration count:  45, Given L1 Memory:  95712, Used L1 Memory:  86228, Reusable Memory: 9484, Used L2 Memory: 0
# ...
#
#
# 	 *** NNTOOL patchifier_rpg Example ***
#
# Entering main controller
# FC Frequency = 370000000 Hz CL Frequency = 370000000 Hz PERIPH Frequency = 370000000 Hz
# Voltage: 800mV
# Constructor
# Call cluster
# Start timer
# Node: S68__scorer_scorer_scorer_0_Conv_fusion, Argument: Input_1, Dim: 3, [1][1][180][240][5] ItemSize: 1 ----> Writing to: S68__scorer_scorer_scorer_0_Conv_fusion_ArgNameInput_1_ItemSize1_Dim3_1x1x180x240x5.dat
# Node: S68__scorer_scorer_scorer_0_Conv_fusion, Argument: S68_Output, Dim: 3, [1][1][178][238][8] ItemSize: 1 ----> Writing to: S68__scorer_scorer_scorer_0_Conv_fusion_ArgNameS68_Output_ItemSize1_Dim3_1x1x178x238x8.dat
# Node: S36__ctx_feat_encoder_conv1_Conv_fusion, Argument: Input_1, Dim: 3, [1][1][180][240][5] ItemSize: 1 ----> Writing to: S36__ctx_feat_encoder_conv1_Conv_fusion_ArgNameInput_1_ItemSize1_Dim3_1x1x180x240x5.dat
# Node: S36__ctx_feat_encoder_conv1_Conv_fusion, Argument: S36_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S36__ctx_feat_encoder_conv1_Conv_fusion_ArgNameS36_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S4__matching_feat_encoder_conv1_Conv_fusion, Argument: Input_1, Dim: 3, [1][1][180][240][5] ItemSize: 1 ----> Writing to: S4__matching_feat_encoder_conv1_Conv_fusion_ArgNameInput_1_ItemSize1_Dim3_1x1x180x240x5.dat
# Node: S4__matching_feat_encoder_conv1_Conv_fusion, Argument: S4_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S4__matching_feat_encoder_conv1_Conv_fusion_ArgNameS4_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S39__ctx_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Argument: S36_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S39__ctx_feat_encoder_layer1_layer1_0_conv1_Conv_fusion_ArgNameS36_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S39__ctx_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Argument: S39_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S39__ctx_feat_encoder_layer1_layer1_0_conv1_Conv_fusion_ArgNameS39_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S42__ctx_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Argument: S39_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S42__ctx_feat_encoder_layer1_layer1_0_conv2_Conv_fusion_ArgNameS39_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S42__ctx_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Argument: S42_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S42__ctx_feat_encoder_layer1_layer1_0_conv2_Conv_fusion_ArgNameS42_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S45__ctx_feat_encoder_layer1_layer1_1_conv1_Conv_fusion, Argument: S42_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S45__ctx_feat_encoder_layer1_layer1_1_conv1_Conv_fusion_ArgNameS42_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S45__ctx_feat_encoder_layer1_layer1_1_conv1_Conv_fusion, Argument: S45_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S45__ctx_feat_encoder_layer1_layer1_1_conv1_Conv_fusion_ArgNameS45_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S48__ctx_feat_encoder_layer1_layer1_1_conv2_Conv_fusion, Argument: S45_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S48__ctx_feat_encoder_layer1_layer1_1_conv2_Conv_fusion_ArgNameS45_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S48__ctx_feat_encoder_layer1_layer1_1_conv2_Conv_fusion, Argument: S48_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S48__ctx_feat_encoder_layer1_layer1_1_conv2_Conv_fusion_ArgNameS48_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S51__ctx_feat_encoder_layer2_layer2_0_conv1_Conv_fusion, Argument: S48_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S51__ctx_feat_encoder_layer2_layer2_0_conv1_Conv_fusion_ArgNameS48_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S51__ctx_feat_encoder_layer2_layer2_0_conv1_Conv_fusion, Argument: S51_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S51__ctx_feat_encoder_layer2_layer2_0_conv1_Conv_fusion_ArgNameS51_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S54__ctx_feat_encoder_layer2_layer2_0_conv2_Conv_fusion, Argument: S51_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S54__ctx_feat_encoder_layer2_layer2_0_conv2_Conv_fusion_ArgNameS51_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S54__ctx_feat_encoder_layer2_layer2_0_conv2_Conv_fusion, Argument: S54_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S54__ctx_feat_encoder_layer2_layer2_0_conv2_Conv_fusion_ArgNameS54_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S57__ctx_feat_encoder_layer2_layer2_1_conv1_Conv_fusion, Argument: S54_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S57__ctx_feat_encoder_layer2_layer2_1_conv1_Conv_fusion_ArgNameS54_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S57__ctx_feat_encoder_layer2_layer2_1_conv1_Conv_fusion, Argument: S57_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S57__ctx_feat_encoder_layer2_layer2_1_conv1_Conv_fusion_ArgNameS57_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S60__ctx_feat_encoder_layer2_layer2_1_conv2_Conv_fusion, Argument: S57_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S60__ctx_feat_encoder_layer2_layer2_1_conv2_Conv_fusion_ArgNameS57_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S60__ctx_feat_encoder_layer2_layer2_1_conv2_Conv_fusion, Argument: S60_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S60__ctx_feat_encoder_layer2_layer2_1_conv2_Conv_fusion_ArgNameS60_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S63__ctx_feat_encoder_conv2_Conv_fusion, Argument: S60_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S63__ctx_feat_encoder_conv2_Conv_fusion_ArgNameS60_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S63__ctx_feat_encoder_conv2_Conv_fusion, Argument: Output_2, Dim: 3, [1][1][45][60][96] ItemSize: 1 ----> Writing to: S63__ctx_feat_encoder_conv2_Conv_fusion_ArgNameOutput_2_ItemSize1_Dim3_1x1x45x60x96.dat
# Node: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Argument: S4_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion_ArgNameS4_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion, Argument: S7_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion_ArgNameS7_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Argument: S7_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion_ArgNameS7_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion, Argument: S10_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion_ArgNameS10_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S13__matching_feat_encoder_layer1_layer1_1_conv1_Conv_fusion, Argument: S10_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S13__matching_feat_encoder_layer1_layer1_1_conv1_Conv_fusion_ArgNameS10_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S13__matching_feat_encoder_layer1_layer1_1_conv1_Conv_fusion, Argument: S13_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S13__matching_feat_encoder_layer1_layer1_1_conv1_Conv_fusion_ArgNameS13_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S16__matching_feat_encoder_layer1_layer1_1_conv2_Conv_fusion, Argument: S13_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S16__matching_feat_encoder_layer1_layer1_1_conv2_Conv_fusion_ArgNameS13_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S16__matching_feat_encoder_layer1_layer1_1_conv2_Conv_fusion, Argument: S16_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S16__matching_feat_encoder_layer1_layer1_1_conv2_Conv_fusion_ArgNameS16_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S19__matching_feat_encoder_layer2_layer2_0_conv1_Conv_fusion, Argument: S16_Output, Dim: 3, [1][1][90][120][32] ItemSize: 1 ----> Writing to: S19__matching_feat_encoder_layer2_layer2_0_conv1_Conv_fusion_ArgNameS16_Output_ItemSize1_Dim3_1x1x90x120x32.dat
# Node: S19__matching_feat_encoder_layer2_layer2_0_conv1_Conv_fusion, Argument: S19_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S19__matching_feat_encoder_layer2_layer2_0_conv1_Conv_fusion_ArgNameS19_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S22__matching_feat_encoder_layer2_layer2_0_conv2_Conv_fusion, Argument: S19_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S22__matching_feat_encoder_layer2_layer2_0_conv2_Conv_fusion_ArgNameS19_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S22__matching_feat_encoder_layer2_layer2_0_conv2_Conv_fusion, Argument: S22_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S22__matching_feat_encoder_layer2_layer2_0_conv2_Conv_fusion_ArgNameS22_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S25__matching_feat_encoder_layer2_layer2_1_conv1_Conv_fusion, Argument: S22_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S25__matching_feat_encoder_layer2_layer2_1_conv1_Conv_fusion_ArgNameS22_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S25__matching_feat_encoder_layer2_layer2_1_conv1_Conv_fusion, Argument: S25_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S25__matching_feat_encoder_layer2_layer2_1_conv1_Conv_fusion_ArgNameS25_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S28__matching_feat_encoder_layer2_layer2_1_conv2_Conv_fusion, Argument: S25_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S28__matching_feat_encoder_layer2_layer2_1_conv2_Conv_fusion_ArgNameS25_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S28__matching_feat_encoder_layer2_layer2_1_conv2_Conv_fusion, Argument: S28_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S28__matching_feat_encoder_layer2_layer2_1_conv2_Conv_fusion_ArgNameS28_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S31__matching_feat_encoder_conv2_Conv_fusion, Argument: S28_Output, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S31__matching_feat_encoder_conv2_Conv_fusion_ArgNameS28_Output_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S31__matching_feat_encoder_conv2_Conv_fusion, Argument: Output_1, Dim: 3, [1][1][45][60][64] ItemSize: 1 ----> Writing to: S31__matching_feat_encoder_conv2_Conv_fusion_ArgNameOutput_1_ItemSize1_Dim3_1x1x45x60x64.dat
# Node: S71__scorer_scorer_scorer_2_Conv_fusion, Argument: S68_Output, Dim: 3, [1][1][178][238][8] ItemSize: 1 ----> Writing to: S71__scorer_scorer_scorer_2_Conv_fusion_ArgNameS68_Output_ItemSize1_Dim3_1x1x178x238x8.dat
# Node: S71__scorer_scorer_scorer_2_Conv_fusion, Argument: S71_Output, Dim: 3, [1][1][176][236][16] ItemSize: 1 ----> Writing to: S71__scorer_scorer_scorer_2_Conv_fusion_ArgNameS71_Output_ItemSize1_Dim3_1x1x176x236x16.dat
# Node: S74__scorer_scorer_scorer_4_Conv_fusion, Argument: S71_Output, Dim: 3, [1][1][176][236][16] ItemSize: 1 ----> Writing to: S74__scorer_scorer_scorer_4_Conv_fusion_ArgNameS71_Output_ItemSize1_Dim3_1x1x176x236x16.dat
# Node: S74__scorer_scorer_scorer_4_Conv_fusion, Argument: S74_Output, Dim: 3, [1][1][174][234][32] ItemSize: 1 ----> Writing to: S74__scorer_scorer_scorer_4_Conv_fusion_ArgNameS74_Output_ItemSize1_Dim3_1x1x174x234x32.dat
# Node: S77__scorer_scorer_scorer_6_Conv_fusion, Argument: S74_Output, Dim: 3, [1][1][174][234][32] ItemSize: 1 ----> Writing to: S77__scorer_scorer_scorer_6_Conv_fusion_ArgNameS74_Output_ItemSize1_Dim3_1x1x174x234x32.dat
# Node: S77__scorer_scorer_scorer_6_Conv_fusion, Argument: Output_3, Dim: 3, [1][1][43][58][1] ItemSize: 1 ----> Writing to: S77__scorer_scorer_scorer_6_Conv_fusion_ArgNameOutput_3_ItemSize1_Dim3_1x1x43x58x1.dat
# Runner completed: 0
#
#       S68__scorer_scorer_scorer_0_Conv_fusion: Cycles:       659014, Cyc%:   1.7%, Operations:     15251040, Op%:   0.8%, Operations/Cycle: 23.142210
#       S36__ctx_feat_encoder_conv1_Conv_fusion: Cycles:      2014918, Cyc%:   5.3%, Operations:     84672000, Op%:   4.3%, Operations/Cycle: 42.022552
#   S4__matching_feat_encoder_conv1_Conv_fusion: Cycles:      2062882, Cyc%:   5.4%, Operations:     84672000, Op%:   4.3%, Operations/Cycle: 41.045490
# S39__ctx_feat_encoder_layer1_layer1_0_conv1_Conv_fusion: Cycles:       789956, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 125.997902
# S42__ctx_feat_encoder_layer1_layer1_0_conv2_Conv_fusion: Cycles:       789237, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 126.112686
# S45__ctx_feat_encoder_layer1_layer1_1_conv1_Conv_fusion: Cycles:       789195, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 126.119400
# S48__ctx_feat_encoder_layer1_layer1_1_conv2_Conv_fusion: Cycles:       789515, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 126.068283
# S51__ctx_feat_encoder_layer2_layer2_0_conv1_Conv_fusion: Cycles:       893569, Cyc%:   2.3%, Operations:     49766400, Op%:   2.5%, Operations/Cycle: 55.693966
# S54__ctx_feat_encoder_layer2_layer2_0_conv2_Conv_fusion: Cycles:       808910, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 123.045578
# S57__ctx_feat_encoder_layer2_layer2_1_conv1_Conv_fusion: Cycles:       773712, Cyc%:   2.0%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 128.643219
# S60__ctx_feat_encoder_layer2_layer2_1_conv2_Conv_fusion: Cycles:       773784, Cyc%:   2.0%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 128.631241
#       S63__ctx_feat_encoder_conv2_Conv_fusion: Cycles:       619908, Cyc%:   1.6%, Operations:     16848000, Op%:   0.9%, Operations/Cycle: 27.178226
# S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion: Cycles:       844834, Cyc%:   2.2%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 117.813438
# S10__matching_feat_encoder_layer1_layer1_0_conv2_Conv_fusion: Cycles:       789602, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 126.054390
# S13__matching_feat_encoder_layer1_layer1_1_conv1_Conv_fusion: Cycles:       789168, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 126.123718
# S16__matching_feat_encoder_layer1_layer1_1_conv2_Conv_fusion: Cycles:       789144, Cyc%:   2.1%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 126.127548
# S19__matching_feat_encoder_layer2_layer2_0_conv1_Conv_fusion: Cycles:       893394, Cyc%:   2.3%, Operations:     49766400, Op%:   2.5%, Operations/Cycle: 55.704872
# S22__matching_feat_encoder_layer2_layer2_0_conv2_Conv_fusion: Cycles:       774062, Cyc%:   2.0%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 128.585052
# S25__matching_feat_encoder_layer2_layer2_1_conv1_Conv_fusion: Cycles:       773034, Cyc%:   2.0%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 128.756042
# S28__matching_feat_encoder_layer2_layer2_1_conv2_Conv_fusion: Cycles:       773153, Cyc%:   2.0%, Operations:     99532800, Op%:   5.1%, Operations/Cycle: 128.736221
#  S31__matching_feat_encoder_conv2_Conv_fusion: Cycles:       427325, Cyc%:   1.1%, Operations:     11232000, Op%:   0.6%, Operations/Cycle: 26.284445
#       S71__scorer_scorer_scorer_2_Conv_fusion: Cycles:       965279, Cyc%:   2.5%, Operations:     47849472, Op%:   2.5%, Operations/Cycle: 49.570614
#       S74__scorer_scorer_scorer_4_Conv_fusion: Cycles:      1638976, Cyc%:   4.3%, Operations:    187619328, Op%:   9.6%, Operations/Cycle: 114.473503
#       S77__scorer_scorer_scorer_6_Conv_fusion: Cycles:      2190693, Cyc%:   5.7%, Operations:     11532256, Op%:   0.6%, Operations/Cycle: 5.264205
#                                       IO_Wait: Cycles:     14957539, Cyc%:  39.0%, Operations:            0, Op%:   0.0%, Operations/Cycle: 0.000000
#
#                                         Total: Cycles:     38370803, Cyc%: 100.0%, Operations:   1952668096, Op%: 100.0%, Operations/Cycle: 50.889423
#
# Ended
# [100%] Built target run
# Script done.

# %%
# If you look at the output of S7 individually
gap9_output = np.fromfile(f"{work_dir}/build/S7__matching_feat_encoder_layer1_layer1_0_conv1_Conv_fusion_ArgNameS7_Output_ItemSize1_Dim3_1x1x90x120x32.dat", dtype=np.int8)
for i, k in enumerate(G.nodes()):
    if k._step_idx==7:
        numpy_output = input_for_gap9[k._step_idx][0]
        numpy_output = numpy_output.astype(np.int8)
        break
gap9_output = gap9_output.reshape(numpy_output.shape)

diff = np.abs(gap9_output - numpy_output)
# The first 19 tiles are numerically correct
print("Difference for first 19 tiles: ", diff[:,:114,:].sum())
# Only the last tile have any errors
print("Difference for last tile: ", diff[:,114:,:].sum())
# Out:
# Difference for first 19 tiles:  0
# Difference for last tile:  0

# %%
# Solution: 
# In test_tutorial/build/BUILD_MODEL/patchifier_rpgKernels.c (generated kernel), 
# Change line 308 from:
#
# NN_In = _NN_In + (192); _LNN_In = ((T0Ind_NextLast)?224:256); _SNN_In = (90*_LNN_In);
#
# to
#  
# NN_In = _NN_In + (192); _LNN_In = ((T0Ind_NextNextLast)?224:256); _SNN_In = (90*_LNN_In); 
#
# Run gap run again to execute main without generating new kernels, error in last tile should disappear
